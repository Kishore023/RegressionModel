# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('HousePrice.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df = df.drop('Id', axis = 1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Let us understand the data

# %%
df.shape
# Out:
# (1460, 80)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# Observe that we have 43 categorical features

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# **Now, let us have a look at missing values :**

# %%
missing = pd.DataFrame(df.isna().sum(), columns = ['Count'])

missing = missing[missing['Count']>0]
missing
# Out:
#               Count
# LotFrontage     259
# Alley          1369
# MasVnrType        8
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# FireplaceQu     690
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# PoolQC         1453
# Fence          1179
# MiscFeature    1406

# %% [markdown]
# **Let us drop those variables with more than 50% missing values**:
#     "  Alley, PoolQC, Fence, MiscFeature   "

# %%
df = df.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature'], axis = 1)

# %% [markdown]
# ### Let us now seperate the numerical features

# %%
X = df.drop('SalePrice', axis =1 )
Y = df['SalePrice']
Y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
num_features = [column for column in X.columns if X[column].dtypes != 'O']

# %%
num_df = X[num_features]
num_df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0          2003       196.0         706           0  ...         548
# 1          1976         0.0         978           0  ...         460
# 2          2002       162.0         486           0  ...         608
# 3          1970         0.0         216           0  ...         642
# 4          2000       350.0         655           0  ...         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
num_df.shape
# Out:
# (1460, 36)

# %%
year_columns = [col for col in num_df.columns if 'Yr'  in col or 'Year' in col]
year_columns
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %% [markdown]
# **1. Separating "Year" based columns**

# %%
Year_df = df[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']]

# %%
Year_df.dtypes
# Out:
# YearBuilt         int64
# YearRemodAdd      int64
# GarageYrBlt     float64
# YrSold            int64
# dtype: object

# %%
len(Year_df['YearBuilt'].unique())
# Out:
# 112

# %%
Year_df.isna().sum()
# Out:
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt     81
# YrSold           0
# dtype: int64

# %%
df.groupby('YrSold')['SalePrice'].median()
# Out:
# YrSold
# 2006    163995
# 2007    167000
# 2008    164000
# 2009    162000
# 2010    155000
# Name: SalePrice, dtype: int64

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
plt.ylabel('Median Sale Price of a Year')
plt.show()

# %% [markdown]
# Here, we can observe that as the time flies on the Median House price is decreasing, this may be because of many years like the age of the house and depending on the house condition

# %% [markdown]
# **2. Discrete/Categorical numerical Features**

# %%
discrete_var = [col for col in num_features if (len(X[col].unique())<25) and col not in year_columns]
discrete_features = X[discrete_var]
discrete_features.head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
discrete_features.shape
# Out:
# (1460, 17)

# %%
discrete_features.isna().sum()
# Out:
# MSSubClass      0
# OverallQual     0
# OverallCond     0
# LowQualFinSF    0
# BsmtFullBath    0
# BsmtHalfBath    0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# KitchenAbvGr    0
# TotRmsAbvGrd    0
# Fireplaces      0
# GarageCars      0
# 3SsnPorch       0
# PoolArea        0
# MiscVal         0
# MoSold          0
# dtype: int64

# %%
for feature in discrete_var:
    data = df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalesPrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# Here, we can see that there are certain features which are exponentially increasing with respect to HousePrice

# %% [markdown]
# **3. Separating the continuous variables**

# %%
continuous_var = [col for col in num_features if (col not in year_columns) and (col not in discrete_var)]
continuous_features = X[continuous_var]
continuous_features.head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch
# 0           61              0            0
# ...

# %%
continuous_features.describe()
# Out:
#        LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1201.000000    1460.000000  1452.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082   103.685262   443.639726    46.549315
# std      24.284752    9981.264932   181.066207   456.098091   161.319273
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      59.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      69.000000    9478.500000     0.000000   383.500000     0.000000
# 75%      80.000000   11601.500000   166.000000   712.250000     0.000000
# max     313.000000  215245.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF    GrLivArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    567.240411  1057.429452  1162.626712   346.992466  1515.463699
# std     441.866955   438.705324   386.587738   436.528436   525.480383
# ...

# %%
continuous_features.shape
# Out:
# (1460, 15)

# %%
continuous_features.isna().sum()
# Out:
# LotFrontage      259
# LotArea            0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# ScreenPorch        0
# dtype: int64

# %%
continuous_features.hist(bins = 30, figsize = (25,20))
plt.show()

# %% [markdown]
# Most of the Continuous Features are skewed, so before feeding to the model we have to transform them- example by using Log Transformations

# %% [markdown]
# **Let us see how this features are correlated to the Target Variable(SalePrice)**

# %%
for feature in continuous_var:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data['SalePrice'] = np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalesPrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# The last two features- 1st floor sq ft and GrLivArea are highly correlated to the Saleprice(Target price)

# %% [markdown]
# **Let us have a look at the outliers in the Numerical Continuous Features**

# %%
for feature in continuous_var:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        sns.boxplot(y =np.log(data[feature]))
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# we can see there are too many outliers

# %% [markdown]
# ### Let us look at Categorical Features:

# %%
cat_features = [col for col in X.columns if X[col].dtype== 'O']
cat_df = X[cat_features]
cat_df.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0      CollgCr       Norm       Norm  ...          Gd        Typ         NaN
# 1      Veenker      Feedr       Norm  ...          TA        Typ          TA
# 2      CollgCr       Norm       Norm  ...          Gd        Typ          TA
# 3      Crawfor       Norm       Norm  ...          Gd        Typ          Gd
# 4      NoRidge       Norm       Norm  ...          Gd        Typ          TA
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %%
cat_df.shape
# Out:
# (1460, 39)

# %%
cat_df.isna().sum()
# Out:
# MSZoning           0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# KitchenQual        0
# Functional         0
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PavedDrive         0
# SaleType           0
# SaleCondition      0
# dtype: int64

# %%
for feature in cat_features:
    data=df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# # Feature Engineering:-

# %% [markdown]
# 1. Handling the missing values
# 2. Encoding the Categorical values
# 3. Handling Skewed data - log transformations
# 4. Handling Outliers
# 5. Feature scaling
